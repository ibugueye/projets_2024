# %%
from pyspark.sql import SparkSession

# Initialisation de la session Spark
spark = SparkSession.builder \
    .appName("Data Processing with Spark") \
    .getOrCreate()

# Lecture des fichiers Parquet depuis le dossier spécifié
input_path = '/home/ibugueye/livrables/ngor_yoff_results_last/*.parquet'
df = spark.read.parquet(input_path)

# Exemple de traitement : Afficher les premières lignes du DataFrame
df.show()

#
# Out:
# +--------------------+--------------+--------------------+-----------------------+--------------------+
# |                path|         label|            features|standard_scale_features|        pca_features|
# +--------------------+--------------+--------------------+-----------------------+--------------------+
# |s3://ngor-yoff/Te...|    Watermelon|[0.01487588509917...|   [-0.7179758847444...|[-6.1051797642081...|
# |s3://ngor-yoff/Te...|    Watermelon|[0.07104229182004...|   [-0.6083942088385...|[-5.1358059500146...|
# |s3://ngor-yoff/Te...|Pineapple Mini|[0.0,4.1723289489...|   [-0.7469990057685...|[-10.883470681318...|
# |s3://ngor-yoff/Te...|Pineapple Mini|[0.0,4.6597709655...|   [-0.7469990057685...|[-5.1053482585690...|
# |s3://ngor-yoff/Te...|    Watermelon|[0.00825151987373...|   [-0.7309001411744...|[-3.4430835379807...|
# |s3://ngor-yoff/Te...|    Watermelon|[0.0,0.2746154069...|   [-0.7469990057685...|[-0.5512291179439...|
# ...

# %%
from airflow import DAG
from airflow.operators.bash_operator import BashOperator
from datetime import datetime

# Définir les arguments par défaut
default_args = {
    'owner': 'airflow',
    'start_date': datetime(2024, 5, 30),
    'retries': 1,
}

# Initialisation du DAG
dag = DAG('spark_processing_dag', default_args=default_args, schedule_interval='@daily')
# Out:
# /tmp/ipykernel_34897/1423860683.py:2 DeprecationWarning: The `airflow.operators.bash_operator.BashOperator` class is deprecated. Please use `'airflow.operators.bash.BashOperator'`.
# /tmp/ipykernel_34897/1423860683.py:13 RemovedInAirflow3Warning: Param `schedule_interval` is deprecated and will be removed in a future release. Please use `schedule` instead.

# %%
from airflow import DAG
from airflow.operators.bash_operator import BashOperator
from datetime import datetime

# Définir les arguments par défaut
default_args = {
    'owner': 'airflow',
    'start_date': datetime(2024, 5, 30),
    'retries': 1,
}

# Initialisation du DAG
dag = DAG('spark_processing_dag', default_args=default_args, schedule_interval='@daily')

# Tâche pour exécuter le script Spark
spark_task = BashOperator(
    task_id='run_spark_script',
    bash_command='python /home/ibugueye/livrables/spark_script.py',  # Remplacez par le chemin réel de votre script
    dag=dag,
)
# Out:
# /tmp/ipykernel_34897/2369173825.py:2 DeprecationWarning: The `airflow.operators.bash_operator.BashOperator` class is deprecated. Please use `'airflow.operators.bash.BashOperator'`.
# /tmp/ipykernel_34897/2369173825.py:13 RemovedInAirflow3Warning: Param `schedule_interval` is deprecated and will be removed in a future release. Please use `schedule` instead.

# %%
! airflow webserver
# Out:
# Please confirm database initialize (or wait 4 seconds to skip it). Are you sure? [y/N]
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ___  ___ |  / _  /   _  __/ _  / / /_/ /_ |/ |/ /
#  _/_/  |_/_/  /_/    /_/    /_/  \____/____/|__/
# Running the Gunicorn Server with:
# Workers: 4 sync
# Host: 0.0.0.0:8080
# Timeout: 120
# Logfiles: - -
# Access Logformat:
# ...
# /home/ibugueye/.local/lib/python3.10/site-packages/flask_limiter/extension.py:333 UserWarning: Using the in-memory storage for tracking rate limits as no storage was explicitly specified. This is not recommended for production use. See: https://flask-limiter.readthedocs.io#configuring-a-storage-backend for documentation about configuring the storage backend.
# [2024-05-31T18:19:19.182+0200] {override.py:924} WARNING - No user yet created, use flask fab command to do it.
# ...

# %%
! airflow schedule
# Out:
# IOStream.flush timed out
# Usage: airflow [-h] GROUP_OR_COMMAND ...
#
# Positional Arguments:
#   GROUP_OR_COMMAND
#
#     Groups
#       config         View configuration
#       connections    Manage connections
#       dags           Manage DAGs
#       db             Database operations
#       jobs           Manage jobs
#       pools          Manage pools
#       providers      Display providers
#       roles          Manage roles
#       tasks          Manage tasks
#       users          Manage users
#       variables      Manage variables
#
#     Commands:
#       cheat-sheet    Display cheat sheet
#       dag-processor  Start a standalone Dag Processor instance
#       info           Show information about current Airflow and environment
#       kerberos       Start a kerberos ticket renewer
#       plugins        Dump information about loaded plugins
#       rotate-fernet-key
#                      Rotate encrypted connection credentials and variables
# ...
